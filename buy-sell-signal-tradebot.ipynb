# %%
import pandas as pd
import numpy as np
import requests
import ta
from ta.volume import VolumeWeightedAveragePrice
from ta.volatility import BollingerBands
from ta.momentum import RSIIndicator, StochasticOscillator, AwesomeOscillatorIndicator
from ta.trend import EMAIndicator, SMAIndicator, WMAIndicator, MACD
from scipy.stats import skew, kurtosis
from datetime import datetime
import warnings
import time
from concurrent.futures import ThreadPoolExecutor

warnings.filterwarnings('ignore')


def get_futures_symbol_list():

    url = 'https://fapi.binance.com/fapi/v1/exchangeInfo'
    data = requests.get(url).json()
    symbols = []
    for s in data['symbols']:
        if s['quoteAsset'] == 'USDT' and s['status'] == 'TRADING':
            if s['symbol'] not in ['KEYUSDT']:
                symbols.append(s['symbol'])
    return symbols


def fetch_futures_ohlcv(symbol, interval='15m', limit=500):

    url = f'https://fapi.binance.com/fapi/v1/klines?symbol={symbol}&interval={interval}&limit={limit}'
    try:
        data = requests.get(url, timeout=10).json()
        if 'code' in data:
            print(f"Error fetching data for {symbol}: {data['msg']}")
            return None
        df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                         'close_time', 'quote_asset_volume', 'number_of_trades',
                                         'taker_buy_base_volume', 'taker_buy_quote_volume', 'ignore'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
        df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume']]
        df[['open', 'high', 'low', 'close', 'volume']] = df[['open', 'high', 'low', 'close', 'volume']].astype(float)
        return df
    except Exception as e:
        print(f"An error occurred while fetching data for {symbol}: {e}")
        return None


def get_all_futures_data(symbols, interval='15m', limit=500):

    all_data = {}
    def fetch_and_store(symbol):
        print(f"Fetching data for {symbol}")
        df = fetch_futures_ohlcv(symbol, interval, limit)
        if df is not None and not df.empty:
            df.set_index('timestamp', inplace=True)
            all_data[symbol] = df

    with ThreadPoolExecutor(max_workers=10) as executor:
        executor.map(fetch_and_store, symbols)

    return all_data


def add_indicators_and_signals(all_data):

    for symbol, df in all_data.items():
        df['ema'] = EMAIndicator(close=df['close'], window=14).ema_indicator()
        df['sma'] = SMAIndicator(close=df['close'], window=14).sma_indicator()
        df['wma'] = WMAIndicator(close=df['close'], window=14).wma()
        df['vwma'] = (df['close'] * df['volume']).rolling(window=14).sum() / df['volume'].rolling(window=14).sum()
        df['rsi'] = RSIIndicator(close=df['close'], window=14).rsi()
        macd = MACD(close=df['close'])
        df['macd_diff'] = macd.macd_diff()
        df['stoch_rsi'] = ta.momentum.StochRSIIndicator(close=df['close'], window=14).stochrsi()
        df['obv'] = ta.volume.OnBalanceVolumeIndicator(close=df['close'], volume=df['volume']).on_balance_volume()
        high_low_avg = (df['high'] + df['low']) / 2
        df['fisher'] = np.arctanh(0.66 * ((high_low_avg - high_low_avg.rolling(5).min()) / (high_low_avg.rolling(5).max() - high_low_avg.rolling(5).min()) - 0.5))
        df['returns'] = df['close'].pct_change()
        df['variance'] = df['returns'].rolling(window=14).var()
        df['std_dev'] = df['returns'].rolling(window=14).std()
        df['skewness'] = df['returns'].rolling(window=14).apply(lambda x: skew(x.dropna()), raw=False)
        df['kurtosis'] = df['returns'].rolling(window=14).apply(lambda x: kurtosis(x.dropna()), raw=False)
        df['price_change'] = df['close'].diff()
        df['price_volume_corr'] = df['price_change'].rolling(window=14).corr(df['volume'])
        df['wt1'] = ta.momentum.WilliamsRIndicator(high=df['high'], low=df['low'], close=df['close'], lbp=9).williams_r()
        df['wt2'] = df['wt1'].rolling(window=3).mean()
        df['wt_cross'] = df['wt1'] - df['wt2']
        df['volume_change'] = df['volume'].pct_change()
        df['volume_increasing'] = df['volume_change'] > 0
        df['volume_increasing_consecutive'] = df['volume_increasing'].rolling(window=5).sum() == 5
        df['signal_strength'] = 0
        df['buy_signal'] = False
        df['sell_signal'] = False
        df['signal_strength'] += np.where(df['ema'] > df['sma'], 1, -1)
        df['signal_strength'] += np.where(df['sma'] > df['wma'], 1, -1)
        df['signal_strength'] += np.where(df['wma'] > df['vwma'], 1, -1)
        df['signal_strength'] += np.where(df['rsi'] < 40, 1, 0)
        df['signal_strength'] += np.where(df['rsi'] > 75, -1, 0)
        df['signal_strength'] += np.where(df['macd_diff'] > 0, 1, -1)
        df['signal_strength'] += np.where(df['stoch_rsi'] < 0.3, 1, 0)
        df['signal_strength'] += np.where(df['stoch_rsi'] > 0.8, -1, 0)
        df['signal_strength'] += np.where(df['obv'] > df['obv'].shift(1), 1, -1)
        df['signal_strength'] += np.where(df['fisher'] > df['fisher'].shift(1), 1, -1)
        df['signal_strength'] += np.where(df['variance'] < df['variance'].rolling(window=3).mean(), 1, 0)
        df['signal_strength'] += np.where(df['std_dev'] < df['std_dev'].rolling(window=3).mean(), 1, 0)
        df['signal_strength'] += np.where(df['skewness'] > 0, 1, -1)
        df['signal_strength'] += np.where(df['kurtosis'] > 3, 1, -1)
        df['signal_strength'] += np.where(df['price_volume_corr'] > 0, 1, -1)
        df['signal_strength'] += np.where(df['wt_cross'] > 0, 1, -1)
        df['signal_strength'] += np.where(df['volume_increasing_consecutive'], 1, 0)
        df['buy_signal'] = df['signal_strength'] >= 10
        df['sell_signal'] = df['signal_strength'] <= -10
        df.dropna(inplace=True)
    return all_data


def backtest(all_data, initial_balance=1000, risk_per_trade=0.01, leverage=5):
    balance = initial_balance
    in_position = False
    position_type = None 
    open_position = None
    entry_price = 0
    position_size = 0
    stop_loss_price = 0
    take_profit_price = 0
    trade_log = []
    commission_rate = 0.0002 
    target_profit_percentage = 0.03  
    stop_loss_percentage = 0.01  

    timestamps = all_data[next(iter(all_data))].index

    for time in timestamps:
        signals = []
        for symbol, df in all_data.items():
            if time in df.index:
                row = df.loc[time]
                if row['buy_signal']:
                    signals.append({'symbol': symbol, 'price': row['close'], 'action': 'buy'})
                elif row['sell_signal']:
                    signals.append({'symbol': symbol, 'price': row['close'], 'action': 'sell'})
        if in_position:
            if time in all_data[open_position].index:
                current_price = all_data[open_position].loc[time]['close']
                if position_type == 'long':
                    profit = (current_price - entry_price) * position_size
                elif position_type == 'short':
                    profit = (entry_price - current_price) * position_size
                if (position_type == 'long' and (current_price <= stop_loss_price or profit <= -max_loss)) or \
                   (position_type == 'short' and (current_price >= stop_loss_price or profit <= -max_loss)):
                    commission_exit = abs(position_size) * current_price * commission_rate
                    balance += profit - commission_exit
                    balance = max(balance, 0)
                    trade_log.append({'time': time, 'symbol': open_position, 'action': 'Exit', 'price': current_price,
                                      'profit': profit - commission_exit, 'balance': balance, 'reason': 'Stop-loss'})
                    print(f"Stop-loss hit for {open_position} ({position_type}) at {current_price:.4f} on {time}, Profit: {profit - commission_exit:.2f}, Balance: {balance:.2f}")
                    in_position = False
                    open_position = None
                elif (position_type == 'long' and current_price >= take_profit_price) or \
                     (position_type == 'short' and current_price <= take_profit_price):
                    commission_exit = abs(position_size) * current_price * commission_rate
                    balance += profit - commission_exit
                    balance = max(balance, 0)
                    trade_log.append({'time': time, 'symbol': open_position, 'action': 'Exit', 'price': current_price,
                                      'profit': profit - commission_exit, 'balance': balance, 'reason': 'Take-profit'})
                    print(f"Take-profit hit for {open_position} ({position_type}) at {current_price:.4f} on {time}, Profit: {profit - commission_exit:.2f}, Balance: {balance:.2f}")
                    in_position = False
                    open_position = None
        else:
            if signals:
                signal_strengths = []
                for signal in signals:
                    symbol = signal['symbol']
                    action = signal['action']
                    df = all_data[symbol]
                    row = df.loc[time]
                    signal_strengths.append({'symbol': symbol, 'action': action, 'price': signal['price'], 'signal_strength': row['signal_strength']})
                best_signal = max(signal_strengths, key=lambda x: abs(x['signal_strength']))
                symbol = best_signal['symbol']
                entry_price = best_signal['price']
                action = best_signal['action']
                max_loss = balance * risk_per_trade
                position_value = balance * leverage
                position_size = position_value / entry_price
                if action == 'buy':
                    position_type = 'long'
                    stop_loss_price = entry_price - (entry_price * stop_loss_percentage)
                    take_profit_price = entry_price + (entry_price * target_profit_percentage)
                elif action == 'sell':
                    position_type = 'short'
                    stop_loss_price = entry_price + (entry_price * stop_loss_percentage)
                    take_profit_price = entry_price - (entry_price * target_profit_percentage)
                commission_entry = position_value * commission_rate
                total_cost = commission_entry
                if total_cost > balance:
                    print(f"Not enough balance to open position for {symbol} at {entry_price:.4f} on {time}")
                    continue
                balance -= commission_entry
                open_position = symbol
                in_position = True
                trade_log.append({'time': time, 'symbol': symbol, 'action': action.capitalize(), 'price': entry_price,
                                  'position_size': position_size, 'balance': balance})
                print(f"{action.capitalize()}ing {symbol} at {entry_price:.4f} on {time}, Position Size: {position_size:.6f}, Balance: {balance:.2f}")

    if in_position:
        current_price = all_data[open_position].iloc[-1]['close']
        if position_type == 'long':
            profit = (current_price - entry_price) * position_size
        elif position_type == 'short':
            profit = (entry_price - current_price) * position_size
        commission_exit = abs(position_size) * current_price * commission_rate
        balance += profit - commission_exit
        balance = max(balance, 0)
        trade_log.append({'time': time, 'symbol': open_position, 'action': 'Exit', 'price': current_price,
                          'profit': profit - commission_exit, 'balance': balance, 'reason': 'End of data'})
        print(f"Closing position for {open_position} ({position_type}) at {current_price:.4f} on {time}, Profit: {profit - commission_exit:.2f}, Balance: {balance:.2f}")

    return balance, trade_log


def main():
    symbols = get_futures_symbol_list()
    symbols = symbols[:300] 

    interval = '15m'
    initial_balance = 1000
    risk_per_trade = 0.01
    leverage = 5

    start_time = time.time()

    all_data = get_all_futures_data(symbols, interval=interval, limit=500)
    all_data = add_indicators_and_signals(all_data)
    if not all_data:
        print("No data available after processing indicators.")
        return
    final_balance, trade_log = backtest(all_data, initial_balance, risk_per_trade, leverage)

    end_time = time.time()
    print(f"\nBacktest completed in {end_time - start_time:.2f} seconds.")

    print(f"\nInitial Balance: {initial_balance}")
    print(f"Final Balance: {final_balance:.2f}")
    profit_percent = ((final_balance - initial_balance) / initial_balance) * 100
    print(f"Total Profit: {profit_percent:.2f}%")

    trades_df = pd.DataFrame(trade_log)
    print("\nTrade Log:")
    print(trades_df)

if __name__ == "__main__":
    main()
# Out:
# Fetching data for BTCUSDT
# Fetching data for ETHUSDT
# Fetching data for BCHUSDT
# Fetching data for XRPUSDT
# Fetching data for EOSUSDT
# Fetching data for LTCUSDT
# Fetching data for TRXUSDT
# Fetching data for ETCUSDT
# Fetching data for LINKUSDT
# Fetching data for XLMUSDT
# Fetching data for ADAUSDT
# Fetching data for XMRUSDT
# Fetching data for DASHUSDT
# Fetching data for ZECUSDT
# Fetching data for XTZUSDT
# Fetching data for BNBUSDT
# Fetching data for ATOMUSDT
# Fetching data for ONTUSDT
# Fetching data for IOTAUSDT
# Fetching data for BATUSDT
# Fetching data for VETUSDT
# Fetching data for NEOUSDT
# Fetching data for QTUMUSDT
# Fetching data for IOSTUSDT
# Fetching data for THETAUSDT
# Fetching data for ALGOUSDT
# Fetching data for ZILUSDT
# Fetching data for KNCUSDT
# Fetching data for ZRXUSDT
# Fetching data for COMPUSDT
# Fetching data for OMGUSDT
# Fetching data for DOGEUSDT
# Fetching data for SXPUSDT
# Fetching data for KAVAUSDT
# Fetching data for BANDUSDT
# Fetching data for RLCUSDT
# Fetching data for MKRUSDT
# Fetching data for SNXUSDT
# Fetching data for DOTUSDT
# Fetching data for DEFIUSDT
# Fetching data for YFIUSDT
# Fetching data for BALUSDT
# Fetching data for CRVUSDT
# Fetching data for TRBUSDT
# Fetching data for RUNEUSDT
# Fetching data for SUSHIUSDT
# Fetching data for EGLDUSDT
# Fetching data for SOLUSDT
# Fetching data for ICXUSDT
# Fetching data for STORJUSDT
# Fetching data for BLZUSDT
# Fetching data for UNIUSDT
# Fetching data for AVAXUSDT
# Fetching data for FTMUSDT
# Fetching data for ENJUSDT
# Fetching data for FLMUSDT
# Fetching data for KSMUSDT
# Fetching data for NEARUSDT
# Fetching data for AAVEUSDT
# Fetching data for FILUSDT
# Fetching data for RSRUSDT
# Fetching data for LRCUSDT
# Fetching data for BELUSDT
# Fetching data for AXSUSDT
# Fetching data for ALPHAUSDT
# Fetching data for ZENUSDT
# Fetching data for SKLUSDT
# Fetching data for GRTUSDT
# Fetching data for 1INCHUSDT
# Fetching data for CHZUSDT
# Fetching data for SANDUSDT
# Fetching data for ANKRUSDT
# Fetching data for LITUSDT
# Fetching data for REEFUSDT
# Fetching data for RVNUSDT
# Fetching data for SFPUSDT
# Fetching data for XEMUSDT
# Fetching data for COTIUSDT
# Fetching data for CHRUSDT
# Fetching data for MANAUSDT
# Fetching data for ALICEUSDT
# Fetching data for HBARUSDT
# Fetching data for ONEUSDT
# Fetching data for LINAUSDT
# Fetching data for STMXUSDT
# Fetching data for DENTUSDT
# Fetching data for CELRUSDT
# Fetching data for HOTUSDT
# Fetching data for MTLUSDT
# Fetching data for OGNUSDT
# Fetching data for NKNUSDT
# Fetching data for 1000SHIBUSDT
# Fetching data for BAKEUSDT
# Fetching data for GTCUSDT
# Fetching data for BTCDOMUSDT
# Fetching data for IOTXUSDT
# Fetching data for C98USDT
# Fetching data for MASKUSDT
# Fetching data for ATAUSDT
# Fetching data for DYDXUSDT
# Fetching data for 1000XECUSDT
# Fetching data for GALAUSDT
# Fetching data for CELOUSDT
# Fetching data for ARUSDT
# Fetching data for ARPAUSDT
# Fetching data for CTSIUSDT
# Fetching data for LPTUSDT
# Fetching data for ENSUSDT
# Fetching data for PEOPLEUSDT
# Fetching data for ROSEUSDT
# Fetching data for DUSKUSDT
# Fetching data for FLOWUSDT
# Fetching data for IMXUSDT
# Fetching data for API3USDT
# Fetching data for GMTUSDT
# Fetching data for APEUSDT
# Fetching data for WOOUSDT
# Fetching data for JASMYUSDT
# Fetching data for DARUSDT
# Fetching data for OPUSDT
# Fetching data for INJUSDT
# Fetching data for STGUSDT
# Fetching data for SPELLUSDT
# Fetching data for 1000LUNCUSDT
# Fetching data for LUNA2USDT
# Fetching data for LDOUSDT
# Fetching data for ICPUSDT
# Fetching data for APTUSDT
# Fetching data for QNTUSDT
# Fetching data for FETUSDT
# Fetching data for FXSUSDT
# Fetching data for HOOKUSDT
# Fetching data for MAGICUSDT
# Fetching data for TUSDT
# Fetching data for HIGHUSDT
# Fetching data for MINAUSDT
# Fetching data for ASTRUSDT
# Fetching data for PHBUSDT
# Fetching data for GMXUSDT
# Fetching data for CFXUSDT
# Fetching data for STXUSDT
# Fetching data for BNXUSDT
# Fetching data for ACHUSDT
# Fetching data for SSVUSDT
# Fetching data for CKBUSDT
# Fetching data for PERPUSDT
# Fetching data for TRUUSDT
# Fetching data for LQTYUSDT
# Fetching data for USDCUSDT
# Fetching data for IDUSDT
# Fetching data for ARBUSDT
# Fetching data for JOEUSDT
# Fetching data for TLMUSDT
# Fetching data for AMBUSDT
# Fetching data for LEVERUSDT
# Fetching data for RDNTUSDT
# Fetching data for HFTUSDT
# Fetching data for XVSUSDT
# Fetching data for BLURUSDT
# Fetching data for EDUUSDT
# Fetching data for SUIUSDT
# Fetching data for 1000PEPEUSDT
# Fetching data for 1000FLOKIUSDT
# Fetching data for UMAUSDT
# Fetching data for COMBOUSDT
# Fetching data for NMRUSDT
# Fetching data for MAVUSDT
# Fetching data for XVGUSDT
# Fetching data for WLDUSDT
# Fetching data for PENDLEUSDT
# Fetching data for ARKMUSDT
# Fetching data for AGLDUSDT
# Fetching data for YGGUSDT
# Fetching data for DODOXUSDT
# Fetching data for BNTUSDT
# Fetching data for OXTUSDT
# Fetching data for SEIUSDT
# Fetching data for CYBERUSDT
# Fetching data for HIFIUSDT
# Fetching data for ARKUSDT
# Fetching data for BICOUSDT
# Fetching data for LOOMUSDT
# Fetching data for BIGTIMEUSDT
# Fetching data for BONDUSDT
# Fetching data for ORBSUSDT
# Fetching data for WAXPUSDT
# Fetching data for BSVUSDT
# Fetching data for RIFUSDT
# Fetching data for POLYXUSDT
# Fetching data for GASUSDT
# Fetching data for POWRUSDT
# Fetching data for TIAUSDT
# Fetching data for CAKEUSDT
# Fetching data for MEMEUSDT
# Fetching data for TWTUSDT
# Fetching data for TOKENUSDT
# Fetching data for ORDIUSDT
# Fetching data for STEEMUSDT
# Fetching data for BADGERUSDT
# Fetching data for ILVUSDT
# Fetching data for NTRNUSDT
# Fetching data for KASUSDT
# Fetching data for BEAMXUSDT
# Fetching data for 1000BONKUSDT
# Fetching data for PYTHUSDT
# Fetching data for SUPERUSDT
# Fetching data for USTCUSDT
# Fetching data for ONGUSDT
# Fetching data for ETHWUSDT
# Fetching data for JTOUSDT
# Fetching data for 1000SATSUSDT
# Fetching data for AUCTIONUSDT
# Fetching data for 1000RATSUSDT
# Fetching data for ACEUSDT
# Fetching data for MOVRUSDT
# Fetching data for NFPUSDT
# Fetching data for AIUSDT
# Fetching data for XAIUSDT
# Fetching data for WIFUSDT
# Fetching data for MANTAUSDT
# Fetching data for ONDOUSDT
# Fetching data for LSKUSDT
# Fetching data for ALTUSDT
# Fetching data for JUPUSDT
# Fetching data for ZETAUSDT
# Fetching data for RONINUSDT
# Fetching data for DYMUSDT
# Fetching data for OMUSDT
# Fetching data for PIXELUSDT
# Fetching data for STRKUSDT
# Fetching data for MAVIAUSDT
# Fetching data for GLMUSDT
# Fetching data for PORTALUSDT
# Fetching data for TONUSDT
# Fetching data for AXLUSDT
# Fetching data for MYROUSDT
# Fetching data for METISUSDT
# Fetching data for AEVOUSDT
# Fetching data for VANRYUSDT
# Fetching data for BOMEUSDT
# Fetching data for ETHFIUSDT
# Fetching data for ENAUSDT
# Fetching data for WUSDT
# Fetching data for TNSRUSDT
# Fetching data for SAGAUSDT
# Fetching data for TAOUSDT
# Fetching data for OMNIUSDT
# Fetching data for REZUSDT
# Fetching data for BBUSDT
# Fetching data for NOTUSDT
# Fetching data for TURBOUSDT
# Fetching data for IOUSDT
# Fetching data for ZKUSDT
# Fetching data for MEWUSDT
# Fetching data for LISTAUSDT
# Fetching data for ZROUSDT
# Fetching data for BTCUSDT_241227
# Fetching data for ETHUSDT_241227
# Fetching data for RENDERUSDT
# Fetching data for BANANAUSDT
# Fetching data for RAREUSDT
# Fetching data for GUSDT
# Fetching data for SYNUSDT
# Fetching data for SYSUSDT
# Fetching data for VOXELUSDT
# Fetching data for BRETTUSDT
# Fetching data for ALPACAUSDT
# Fetching data for POPCATUSDT
# Fetching data for SUNUSDT
# Fetching data for VIDTUSDT
# Fetching data for NULSUSDT
# Fetching data for DOGSUSDT
# Fetching data for MBOXUSDT
# Fetching data for CHESSUSDT
# Fetching data for FLUXUSDT
# Fetching data for BSWUSDT
# Fetching data for QUICKUSDT
# Fetching data for NEIROETHUSDT
# Fetching data for RPLUSDT
# Fetching data for AERGOUSDT
# Fetching data for POLUSDT
# Fetching data for UXLINKUSDT
# Fetching data for 1MBABYDOGEUSDT
# Fetching data for NEIROUSDT
# Fetching data for KDAUSDT
# Fetching data for FIDAUSDT
# Fetching data for FIOUSDT
# Fetching data for CATIUSDT
# Fetching data for GHSTUSDT
# Fetching data for LOKAUSDT
# Fetching data for HMSTRUSDT
# Fetching data for BTCUSDT_250328
# Fetching data for ETHUSDT_250328
# Fetching data for REIUSDT
# Fetching data for COSUSDT
# Fetching data for EIGENUSDT
# Fetching data for DIAUSDT
# Fetching data for 1000CATUSDT
# Fetching data for SCRUSDT
# Fetching data for GOATUSDT
# Buying NOTUSDT at 0.0090 on 2024-12-02 00:15:00, Position Size: 557289.344628, Balance: 999.00
# Stop-loss hit for NOTUSDT (long) at 0.0089 on 2024-12-02 00:45:00, Profit: -26.07, Balance: 972.93
# Buying PENDLEUSDT at 5.4722 on 2024-12-02 12:00:00, Position Size: 888.972438, Balance: 971.95
# Take-profit hit for PENDLEUSDT (long) at 5.6490 on 2024-12-02 13:45:00, Profit: 156.17, Balance: 1128.12
# Selling CTSIUSDT at 0.2154 on 2024-12-03 03:30:00, Position Size: 26186.630318, Balance: 1126.99
# Stop-loss hit for CTSIUSDT (short) at 0.2173 on 2024-12-03 04:00:00, Profit: -50.89, Balance: 1076.10
# Buying SKLUSDT at 0.0750 on 2024-12-03 17:45:00, Position Size: 71768.657163, Balance: 1075.02
# Stop-loss hit for SKLUSDT (long) at 0.0747 on 2024-12-03 19:00:00, Profit: -20.45, Balance: 1054.57
# Selling NULSUSDT at 0.5576 on 2024-12-04 00:30:00, Position Size: 9456.361057, Balance: 1053.52
# Take-profit hit for NULSUSDT (short) at 0.5397 on 2024-12-04 01:00:00, Profit: 168.25, Balance: 1221.77
# Selling TIAUSDT at 8.1471 on 2024-12-04 03:45:00, Position Size: 749.817085, Balance: 1220.55
# Stop-loss hit for TIAUSDT (short) at 8.2682 on 2024-12-04 04:00:00, Profit: -92.04, Balance: 1128.50
# Buying REIUSDT at 0.0855 on 2024-12-04 11:30:00, Position Size: 66009.733944, Balance: 1127.37
# Stop-loss hit for REIUSDT (long) at 0.0848 on 2024-12-04 11:45:00, Profit: -49.31, Balance: 1078.07
# Buying SUPERUSDT at 1.7883 on 2024-12-05 12:30:00, Position Size: 3014.225629, Balance: 1076.99
# Stop-loss hit for SUPERUSDT (long) at 1.7625 on 2024-12-05 13:00:00, Profit: -78.83, Balance: 998.16
#
# Backtest completed in 311.70 seconds.
#
# Initial Balance: 1000
# Final Balance: 998.16
# Total Profit: -0.18%
#
# Trade Log:
#                   time      symbol action     price  position_size  \
# 0  2024-12-02 00:15:00     NOTUSDT    Buy  0.008972  557289.344628
# 1  2024-12-02 00:45:00     NOTUSDT   Exit  0.008927            NaN
# 2  2024-12-02 12:00:00  PENDLEUSDT    Buy  5.472200     888.972438
# 3  2024-12-02 13:45:00  PENDLEUSDT   Exit  5.649000            NaN
# 4  2024-12-03 03:30:00    CTSIUSDT   Sell  0.215400   26186.630318
# 5  2024-12-03 04:00:00    CTSIUSDT   Exit  0.217300            NaN
# 6  2024-12-03 17:45:00     SKLUSDT    Buy  0.074970   71768.657163
# 7  2024-12-03 19:00:00     SKLUSDT   Exit  0.074700            NaN
# 8  2024-12-04 00:30:00    NULSUSDT   Sell  0.557600    9456.361057
# 9  2024-12-04 01:00:00    NULSUSDT   Exit  0.539700            NaN
# 10 2024-12-04 03:45:00     TIAUSDT   Sell  8.147100     749.817085
# 11 2024-12-04 04:00:00     TIAUSDT   Exit  8.268200            NaN
# 12 2024-12-04 11:30:00     REIUSDT    Buy  0.085480   66009.733944
# 13 2024-12-04 11:45:00     REIUSDT   Exit  0.084750            NaN
# 14 2024-12-05 12:30:00   SUPERUSDT    Buy  1.788300    3014.225629
# 15 2024-12-05 13:00:00   SUPERUSDT   Exit  1.762500            NaN
#
#         balance      profit       reason
# 0    999.000000         NaN          NaN
# 1    972.926995  -26.073005    Stop-loss
# 2    971.954068         NaN          NaN
# 3   1128.120034  156.165966  Take-profit
# 4   1126.991914         NaN          NaN
# 5   1076.099245  -50.892669    Stop-loss
# 6   1075.023146         NaN          NaN
# 7   1054.573385  -20.449761    Stop-loss
# 8   1053.518812         NaN          NaN
# 9   1221.766955  168.248143  Take-profit
# 10  1220.545188         NaN          NaN
# 11  1128.502412  -92.042777    Stop-loss
# 12  1127.373909         NaN          NaN
# 13  1078.067938  -49.305971    Stop-loss
# 14  1076.989870         NaN          NaN
# 15   998.160335  -78.829536    Stop-loss
